# %%
#NYC Project

# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
from pathlib import Path

# %%
energy_file = Path("Resources/Energy_data.csv")
traffic_file = Path("Resources/Traffic_data.csv")
gas_file = Path("Resources/Gas_data.csv")

# %%
energy_df = pd.read_csv(energy_file)
energy_df.head()
# Out:
#   Development Name Borough Account Name Location Meter AMR   Meter Scope  \
# 0            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 1            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 2            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 3            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 4            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
#
#    TDS #  EDP  RC Code Funding Source  ... Meter Number Estimated  \
# 0  118.0  248  B011800        FEDERAL  ...      2779378         N
# 1  118.0  248  B011800        FEDERAL  ...      2779378         N
# 2  118.0  248  B011800        FEDERAL  ...      2779378         N
# 3  118.0  248  B011800        FEDERAL  ...      2779378         N
# 4  118.0  248  B011800        FEDERAL  ...      2779378         N
#
#    Current Charges   Rate Class Bill Analyzed Consumption (KWH)  KWH Charges  \
# 0         18835.31  GOV/NYC/068           Yes          128800.0      4985.85
# 1         14820.55  GOV/NYC/068           Yes          112800.0      4366.49
# 2         21081.97  GOV/NYC/068           Yes          106400.0      4118.74
# 3         17534.60  GOV/NYC/068           Yes          109600.0      4242.62
# 4         20979.09  GOV/NYC/068           Yes          117600.0      4552.30
#
#   Consumption (KW) KW Charges  Other charges
# 0            216.0    2540.16       11309.30
# 1            192.0    2257.92        8196.14
# 2            192.0    2257.92       14705.31
# 3            184.0    2163.84       11128.14
# 4            256.0    3010.56       13416.23
#
# [5 rows x 27 columns]

# %%
traffic_df = pd.read_csv(traffic_file)
traffic_df.head()
# Out:
#      Month  Bus Ridership  Subway Ridership  AAR Ridership  LIRR Ridership  \
# 0  2019-01       44534038         134544724         864139         7166693
# 1  2019-02       42141027         126359734         853607         6544351
# 2  2019-03       48332949         143723256         949831         7515113
# 3  2019-04       47233653         145063237         922701         7724038
# 4  2019-05       49821526         150789403         910525         7974945
#
#    MNR Ridership         B&T
# 0        6860312  25129910.0
# 1        6200044  23640999.0
# 2        7098004  27460314.0
# 3        7459243  27543316.0
# 4        7227827  29367794.0

# %%
gas_df = pd.read_csv(gas_file)
gas_df.head()
# Out:
#      Month  NY Conventional Gasoline Spot Price ($/gal)
# 0  2019-01                                       1.4275
# 1  2019-02                                       1.5150
# 2  2019-03                                       1.7880
# 3  2019-04                                       2.0400
# 4  2019-05                                       1.9280

# %%
#1(A). How has the energy price and energy consumption changed over time? Are they correlated?
# Histogram
# Energy Price Over Time
fig,ax = plt.subplots(1,1)
a = energy_df["Current Charges"]
ax.hist(a, bins = [len(energy_df["Revenue Month"])])
ax.set_title("Energy Price Over TIme Before and After Covid")
ax.set_xlabel('Date by Month')
ax.set_ylabel('Energy Price')
plt.show()

# %%
#1(A). How has the energy price and energy consumption changed over time? Are they correlated?
# Histogram
# Energy Consumption (KWH) Over Time
fig,ax = plt.subplots(1,1)
a = energy_df["Consumption (KWH)"]
ax.hist(a, bins = [len(energy_df["Revenue Month"])])
ax.set_title("Energy Price Over TIme Before and After Covid")
ax.set_xlabel('Date by Month')
ax.set_ylabel('Energy Consumption (KWH)')
plt.show()

# %%
#1(B). How has the energy price and energy consumption changed over time? Are they correlated?
# Line Chart
# Energy Price Over Time
plt.scatter(energy_df["Revenue Month"], energy_df["Current Charges"])
plt.xlabel("Date by Month")
plt.ylabel("Energy Price")
plt.title("NYC Price of Energy Before and After Covid")
plt.xticks(rotation = 90)
plt.xticks(range(1, 48, 2))
plt.show()

# %%
#1(B). How has the energy price and energy consumption changed over time? Are they correlated?
# Line Chart
# Energy Consumption Over Time
plt.scatter(energy_df["Revenue Month"], energy_df["Consumption (KWH)"])
plt.xlabel("Date by Month")
plt.ylabel("Energy Consumption (KWH)")
plt.title("NYC Consumption of Energy Before and After Covid")
plt.xticks(rotation = 90)
plt.xticks(range(1, 48, 2))
plt.show()

# %%
#2(B) Has the consumer usage of cars/buses affected gas prices?
# Line Chart
# Combine the data into a single DataFrame
combined_data = pd.merge(traffic_df, gas_df, on="Month")
#combined_data.head()
# Line Chart
# Setting Variables
x = combined_data["Month"]
y = combined_data["B&T"]/10000000
z = combined_data["NY Conventional Gasoline Spot Price ($/gal)"]
# plot lines
plt.plot(x, y, label = "Bridges & Tunnels")
plt.plot(x, z, label = "Gas Price")
plt.legend()
plt.xticks(range(1, 48, 2))
plt.xticks(rotation = 90)
plt.xlabel("Month")
plt.ylabel("B&T (in 10M)")
plt.title("Bridges & Tunnels vs. Gas Price")
plt.show()

# %%
#3(A). Has public transportation usage returned to pre-pandemic levels?
# Line Chart
# Setting Variables
x = traffic_df["Month"]
y = traffic_df["Bus Ridership"]
z = traffic_df["Subway Ridership"]
a = traffic_df["AAR Ridership"]
b = traffic_df["LIRR Ridership"]
c = traffic_df["MNR Ridership"]
d = traffic_df["B&T"]
# plot lines
plt.plot(x, y, label = "Bus Ridership")
plt.plot(x, z, label = "Subway Ridership")
plt.plot(x, a, label = "AAR Ridership")
plt.plot(x, b, label = "LIRR Ridership")
plt.plot(x, c, label = "MNR Ridership")
plt.plot(x, d, label = "B&T")
plt.legend()
plt.xticks(rotation = 90)
plt.xticks(range(1, 48, 2))
plt.xlabel("Date by Month")
plt.ylabel("Ridership Number")
plt.title("NYC Ridership by Type Before & After Covid")
plt.show()

# %%
#3(B). Has public transportation usage returned to pre-pandemic levels?
# Bar Chart
# Setting Variables
x = traffic_df["Month"]
y = traffic_df["Bus Ridership"]
z = traffic_df["Subway Ridership"]
a = traffic_df["AAR Ridership"]
b = traffic_df["LIRR Ridership"]
c = traffic_df["MNR Ridership"]
d = traffic_df["B&T"]
# plot bars
plt.bar(x, y, label = "Bus Ridership")
plt.bar(x, z, label = "Subway Ridership")
plt.bar(x, a, label = "AAR Ridership")
plt.bar(x, b, label = "LIRR Ridership")
plt.bar(x, c, label = "MNR Ridership")
plt.bar(x, d, label = "B&T")
plt.legend()
plt.xticks(rotation = 90)
plt.xticks(range(1, 48, 2))
plt.xlabel("Date by Month")
plt.ylabel("Ridership Number")
plt.title("NYC Ridership by Type Before & After Covid")
plt.show()

# %%
#4(A). Has preference for public transportation changed after 2020?
# Before Pie Chart
before_df = #create dataframe for before 2020 transportation
